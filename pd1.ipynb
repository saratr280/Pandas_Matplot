# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
na_vals = ["NA", "Missing"]
df = pd.read_csv("data/survey_results_public.csv", index_col = "ResponseId", na_values=na_vals)
schema_df = pd.read_csv("data/survey_results_schema.csv", index_col = "qname")

# %%
pd.set_option("display.max_columns", 79)
pd.set_option("display.max_rows", 79)

# %%
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# ...

# %%
df.shape
# Out:
# (73268, 78)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'RemoteWork', 'CodingActivities', 'EdLevel',
#        'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool',
#        'Country', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OpSysProfessional use', 'OpSysPersonal use', 'VersionControlSystem',
#        'VCInteraction', 'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df["RemoteWork"].value_counts()
# Out:
# Fully remote                            25341
# Hybrid (some remote, some in-person)    25021
# Full in-person                           8596
# Name: RemoteWork, dtype: int64

# %%
df.loc[1000:1015, "EdLevel" : "DevType"]
# Out:
#                                                       EdLevel  \
# ResponseId
# 1000        Secondary school (e.g. American high school, G...
# 1001             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1002        Secondary school (e.g. American high school, G...
# 1003        Some college/university study without earning ...
# 1004          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1005          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1006             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1007        Some college/university study without earning ...
# 1008          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1009          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1010             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1011          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1012             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1013          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
df["Currency"].value_counts()
# Out:
# EUR European Euro              12634
# USD\tUnited States dollar      12346
# INR\tIndian rupee               4229
# GBP\tPound sterling             3318
# CAD\tCanadian dollar            1847
#                                ...
# BND\tBrunei dollar                 1
# PGK\tPapua New Guinean kina        1
# SHP\tSaint Helena pound            1
# GIP\tGibraltar pound               1
# TOP\tTongan pa’anga                1
# Name: Currency, Length: 142, dtype: int64

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# S1                      QID1
# MainBranch              QID2
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# CompFreq               QID52
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# MiscTech              QID265
# ToolsTech             QID275
# NEWCollabTools        QID274
# ...

# %%
schema_df.loc["DevType", "question"]
# Out:
# 'Which of the following describes your current job? Please select all that apply.'

# %%
schema_df.loc["PurchaseInfluence", "question"]
# Out:
# 'What level of influence do you, personally, have over new technology purchases at your organization?'

# %%
schema_df.sort_index(ascending=False, inplace=True)
schema_df
# Out:
#                          qid  \
# qname
# YearsCodePro           QID34
# YearsCode              QID32
# WorkExp               QID288
# Webframe              QID264
# VersionControlSystem  QID283
# VCInteraction         QID284
# VCHosting             QID285
# TrueFalse_3           QID294
# TrueFalse_2           QID294
# TrueFalse_1           QID294
# TrueFalse             QID294
# Trans                 QID153
# ToolsTech             QID275
# TimeSearching         QID291
# TimeAnswering         QID292
# TBranch               QID299
# SurveyLength          QID132
# SurveyEase            QID133
# Sexuality             QID136
# SOVisitFreq           QID100
# SOTeamsUsage          QID286
# SOPartFreq            QID102
# SOComm                QID106
# SOAccount             QID101
# S7                    QID131
# S6                    QID295
# S5                    QID121
# S4                     QID91
# S3                     QID61
# S2                    QID190
# ...

# %%
schema_df.loc["CompTotal", "question"]
# Out:
# 'What is your current total compensation (salary, bonuses, and perks, before taxes and deductions)? Please enter a whole number in the box below, without any punctuation.  If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.'

# %%
high_salary = (df["CompTotal"] > 150000)

# %%
df.loc[high_salary, ["Country", "CompTotal", "LanguageHaveWorkedWith"]]
# Out:
#                                  Country    CompTotal  \
# ResponseId
# 12              United States of America     194400.0
# 18                               Austria     190000.0
# 54              United States of America     170000.0
# 55                                Norway    1000000.0
# 57                                Taiwan    1632000.0
# ...                                  ...          ...
# 73224           United States of America     200000.0
# 73230           United States of America     325000.0
# 73233                            Uruguay     215000.0
# 73238       Iran, Islamic Republic of...  300000000.0
# 73259                              India    3200000.0
#
#                                        LanguageHaveWorkedWith
# ResponseId
# 12          C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 18                                                 Python;SQL
# 54                      C#;HTML/CSS;JavaScript;SQL;TypeScript
# ...

# %%
countries = ["United States of America", "India", "Austria", "Norway", "Taiwan", "Saudi Arabia"]
filt = df["Country"].isin(countries)

# %%
df.loc[filt, "Country"]
# Out:
# ResponseId
# 5        United States of America
# 7                           India
# 8                           India
# 12       United States of America
# 13       United States of America
#                    ...
# 73256                       India
# 73258                       India
# 73259                       India
# 73265    United States of America
# 73266    United States of America
# Name: Country, Length: 21843, dtype: object

# %%
filt2 = (df["LanguageHaveWorkedWith"].str.contains("Python", na=False)) | ("Country" == "Saudi Arabia")

# %%
df.loc[filt2, ["Country", "CompTotal", "LanguageHaveWorkedWith"] ]
# Out:
#                                                       Country  CompTotal  \
# ResponseId
# 3           United Kingdom of Great Britain and Northern I...    32000.0
# 7                                                       India        NaN
# 12                                   United States of America   194400.0
# 15                                   United States of America   110000.0
# 17                                             Czech Republic    37000.0
# ...                                                       ...        ...
# 73258                                                   India        NaN
# 73262                                                  France    36000.0
# 73264                                                 Nigeria    60000.0
# 73265                                United States of America   107000.0
# 73266                                United States of America        NaN
#
#                                        LanguageHaveWorkedWith
# ResponseId
# ...

# %%
df.rename(columns={"ConvertedCompYearly": "salaryUSDYearly"}, inplace=True)

# %%
df["salaryUSDYearly"]
# Out:
# ResponseId
# 1             NaN
# 2             NaN
# 3         40205.0
# 4        215232.0
# 5             NaN
#            ...
# 73264         NaN
# 73265         NaN
# 73266         NaN
# 73267         NaN
# 73268         NaN
# Name: salaryUSDYearly, Length: 73268, dtype: float64

# %%
df["TBranch"]
# Out:
# ResponseId
# 1        NaN
# 2         No
# 3         No
# 4         No
# 5         No
#         ...
# 73264    Yes
# 73265    Yes
# 73266    Yes
# 73267     No
# 73268    NaN
# Name: TBranch, Length: 73268, dtype: object

# %%
df["TBranch"].map({"Yes": True, "No": False}).value_counts()
# Out:
# True     37200
# False    15470
# Name: TBranch, dtype: int64

# %%
df["Trans"].map({"Yes": True, "No": False}).value_counts()
# Out:
# False    67392
# True      1064
# Name: Trans, dtype: int64

# %%
d = df["Country"] == "United States of America"
df.drop(index=df[d].index)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 6           I am not primarily a developer, but I write co...
# ...                                                       ...
# 73262                          I am a developer by profession
# 73263                                   I am learning to code
# 73264                          I am a developer by profession
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
df.sort_values(by="YearsCode", ascending= False, inplace=True)

# %%
df["YearsCode"].head(50)
# Out:
# ResponseId
# 43019    More than 50 years
# 59280    More than 50 years
# 46149    More than 50 years
# 13265    More than 50 years
# 63399    More than 50 years
# 40906    More than 50 years
# 19765    More than 50 years
# 59650    More than 50 years
# 67878    More than 50 years
# 65178    More than 50 years
# 31097    More than 50 years
# 10832    More than 50 years
# 58740    More than 50 years
# 31152    More than 50 years
# 7737     More than 50 years
# 67843    More than 50 years
# 64686    More than 50 years
# 46134    More than 50 years
# 46129    More than 50 years
# 23845    More than 50 years
# 39940    More than 50 years
# 50096    More than 50 years
# 57567    More than 50 years
# 55908    More than 50 years
# 13114    More than 50 years
# 17250    More than 50 years
# 57032    More than 50 years
# 50113    More than 50 years
# 50606    More than 50 years
# 63472    More than 50 years
# 25632    More than 50 years
# 57029    More than 50 years
# ...

# %%
df.sort_values(by=["Country", "CompTotal"], ascending=[True, False] , inplace=True)

# %%
df[["Country", "CompTotal"]].head(50)
# Out:
#                 Country   CompTotal
# ResponseId
# 6892        Afghanistan  55000000.0
# 38513       Afghanistan   1200000.0
# 43640       Afghanistan    700000.0
# 43691       Afghanistan    100000.0
# 23224       Afghanistan     40000.0
# 6243        Afghanistan     40000.0
# 2449        Afghanistan     40000.0
# 49274       Afghanistan      6000.0
# 55666       Afghanistan       200.0
# 5465        Afghanistan         1.0
# 3887        Afghanistan         1.0
# 6777        Afghanistan         1.0
# 17470       Afghanistan         1.0
# 2738        Afghanistan         0.0
# 67667       Afghanistan         0.0
# 60626       Afghanistan         NaN
# 10234       Afghanistan         NaN
# 56189       Afghanistan         NaN
# 67566       Afghanistan         NaN
# 28435       Afghanistan         NaN
# 60147       Afghanistan         NaN
# 61936       Afghanistan         NaN
# 13852       Afghanistan         NaN
# 61768       Afghanistan         NaN
# ...

# %%
df["CompTotal"].nlargest(10)
# Out:
# ResponseId
# 35787    9.000000e+56
# 3069     1.000000e+52
# 70598    1.000000e+22
# 17568    1.000000e+15
# 19245    5.000000e+12
# 24641    1.500070e+12
# 31191    1.000000e+12
# 71604    9.363220e+09
# 34412    7.200000e+09
# 49875    6.438169e+09
# Name: CompTotal, dtype: float64

# %%
df.nlargest(10, "CompTotal")
# Out:
#                                                    MainBranch  \
# ResponseId
# 35787                          I am a developer by profession
# 3069                           I am a developer by profession
# 70598                          I am a developer by profession
# 17568                          I am a developer by profession
# 19245       I am not primarily a developer, but I write co...
# 24641                          I am a developer by profession
# 31191                          I am a developer by profession
# 71604                          I am a developer by profession
# 34412                          I am a developer by profession
# 49875                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 35787                 Employed, full-time;Employed, part-time
# 3069                                      Employed, full-time
# 70598       Independent contractor, freelancer, or self-em...
# ...

# %%
df.nsmallest(10, "CompTotal")
# Out:
#                                                    MainBranch  \
# ResponseId
# 2738                           I am a developer by profession
# 67667                          I am a developer by profession
# 22778                          I am a developer by profession
# 57029       I am not primarily a developer, but I write co...
# 27811                          I am a developer by profession
# 64664                          I am a developer by profession
# 58997                          I am a developer by profession
# 30855                          I am a developer by profession
# 15641       I am not primarily a developer, but I write co...
# 51759                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 2738                                      Employed, full-time
# 67667                                     Employed, full-time
# 22778                                     Employed, full-time
# ...

# %%
df["CompTotal"].median()
# Out:
# 77500.0

# %%
df["EdLevel"].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          30276
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       15486
# Some college/university study without earning a degree                                 9326
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     7904
# Associate degree (A.A., A.S., etc.)                                                    2236
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             2169
# Primary/elementary school                                                              1806
# Something else                                                                         1247
# Professional degree (JD, MD, etc.)                                                     1121
# Name: EdLevel, dtype: int64

# %%
df["Country"].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Seychelles                                                  1
# Monaco                                                      1
# Solomon Islands                                             1
# Burkina Faso                                                1
# Djibouti                                                    1
# Name: Country, Length: 180, dtype: int64

# %%
country_grp = df.groupby(["Country"])

# %%
country_grp.get_group("Saudi Arabia")
# Out:
#                                                    MainBranch  \
# ResponseId
# 63647                          I am a developer by profession
# 26204                          I am a developer by profession
# 12931                          I am a developer by profession
# 40541                          I am a developer by profession
# 68976                          I am a developer by profession
# ...                                                       ...
# 63287       I am not primarily a developer, but I write co...
# 10430                                   I am learning to code
# 51965                          I am a developer by profession
# 12341                             I code primarily as a hobby
# 15422                                   I am learning to code
#
#                                                    Employment  \
# ResponseId
# 63647                                     Employed, part-time
# 26204                                     Employed, full-time
# ...

# %%
country_grp.get_group("Saudi Arabia")["EdLevel"].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          50
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    22
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       20
# Primary/elementary school                                                              9
# Some college/university study without earning a degree                                 6
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             2
# Associate degree (A.A., A.S., etc.)                                                    2
# Professional degree (JD, MD, etc.)                                                     2
# Something else                                                                         1
# Name: EdLevel, dtype: int64

# %%
country_grp["EdLevel"].value_counts().head(50)
# Out:
# Country              EdLevel
# Afghanistan          Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                           26
#                      Primary/elementary school                                                               9
#                      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                         8
#                      Some college/university study without earning a degree                                  8
#                      Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)      6
#                      Something else                                                                          5
#                      Associate degree (A.A., A.S., etc.)                                                     2
#                      Other doctoral degree (Ph.D., Ed.D., etc.)                                              2
# ...

# %%
country_grp["EdLevel"].value_counts(normalize=True).loc["United States of America"]
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          0.491010
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       0.176693
# Some college/university study without earning a degree                                0.130078
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    0.073252
# Associate degree (A.A., A.S., etc.)                                                   0.044913
# Other doctoral degree (Ph.D., Ed.D., etc.)                                            0.038772
# Primary/elementary school                                                             0.027895
# Something else                                                                        0.010285
# Professional degree (JD, MD, etc.)                                                    0.007103
# Name: EdLevel, dtype: float64

# %%
country_grp["CompTotal"].median().head(60)
# Out:
# Country
# Afghanistan                            6000.0
# Albania                                5500.0
# Algeria                               75000.0
# Andorra                               31500.0
# Angola                               600000.0
# Antigua and Barbuda                       NaN
# Argentina                            110000.0
# Armenia                              632500.0
# Australia                            125000.0
# Austria                               49750.0
# Azerbaijan                             3500.0
# Bahamas                                   NaN
# Bahrain                                2865.0
# Bangladesh                            60000.0
# Barbados                             100000.0
# Belarus                                3600.0
# Belgium                                4600.0
# Belize                                    NaN
# Benin                               1000000.0
# Bhutan                               330000.0
# ...

# %%
country_grp["CompTotal"].agg(["median", "mean"]).loc["Saudi Arabia"]
# Out:
# median    2.000000e+04
# mean      1.066029e+06
# Name: Saudi Arabia, dtype: float64

# %%
country_uses_python = country_grp["LanguageHaveWorkedWith"].apply(lambda x: x.str.contains("Python").sum())
country_uses_python
# Out:
# Country
# Afghanistan                              25
# Albania                                  19
# Algeria                                  19
# Andorra                                   4
# Angola                                    3
#                                        ...
# Venezuela, Bolivarian Republic of...     52
# Viet Nam                                136
# Yemen                                     4
# Zambia                                    6
# Zimbabwe                                 11
# Name: LanguageHaveWorkedWith, Length: 180, dtype: int64

# %%
country_respondents = df["Country"].value_counts()
country_respondents
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Seychelles                                                  1
# Monaco                                                      1
# Solomon Islands                                             1
# Burkina Faso                                                1
# Djibouti                                                    1
# Name: Country, Length: 180, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis="columns", sort=False)
python_df
# Out:
#                                                     Country  \
# United States of America                              13543
# India                                                  6639
# Germany                                                5395
# United Kingdom of Great Britain and Northern Ir...     4190
# Canada                                                 2490
# ...                                                     ...
# Seychelles                                                1
# Monaco                                                    1
# Solomon Islands                                           1
# Burkina Faso                                              1
# Djibouti                                                  1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                              7017
# India                                                                 3081
# ...

# %%
python_df.rename(columns={"Country": "NumRespondents", "LanguageHaveWorkedWith": "NumKnowsPython"}, inplace=True)

# %%
python_df
# Out:
#                                                     NumRespondents  \
# United States of America                                     13543
# India                                                         6639
# Germany                                                       5395
# United Kingdom of Great Britain and Northern Ir...            4190
# Canada                                                        2490
# ...                                                            ...
# Seychelles                                                       1
# Monaco                                                           1
# Solomon Islands                                                  1
# Burkina Faso                                                     1
# Djibouti                                                         1
#
#                                                     NumKnowsPython
# United States of America                                      7017
# ...

# %%
python_df["PctKnowsPython"] = (python_df["NumKnowsPython"]/python_df["NumRespondents"]) * 100
python_df
# Out:
#                                                     NumRespondents  \
# United States of America                                     13543
# India                                                         6639
# Germany                                                       5395
# United Kingdom of Great Britain and Northern Ir...            4190
# Canada                                                        2490
# ...                                                            ...
# Seychelles                                                       1
# Monaco                                                           1
# Solomon Islands                                                  1
# Burkina Faso                                                     1
# Djibouti                                                         1
#
#                                                     NumKnowsPython  \
# United States of America                                      7017
# ...

# %%
python_df.sort_values(by="PctKnowsPython", ascending=False, inplace=True)

# %%
python_df.head(50)
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Burkina Faso                                   1               1
# Solomon Islands                                1               1
# Saint Kitts and Nevis                          1               1
# Brunei Darussalam                              1               1
# Fiji                                           2               2
# Papua New Guinea                               2               2
# North Korea                                    4               4
# Lao People's Democratic Republic               7               6
# Timor-Leste                                    4               3
# Suriname                                       4               3
# Democratic Republic of the Congo               7               5
# Mali                                          10               7
# Kuwait                                        20              14
# ...

# %%
python_df.loc["Saudi Arabia"]
# Out:
# NumRespondents    116.000000
# NumKnowsPython     54.000000
# PctKnowsPython     46.551724
# Name: Saudi Arabia, dtype: float64

# %%
df["YearsCode"].unique()
# Out:
# array(['3', '40', '12', '8', '9', '4', '15', '25', 'Less than 1 year',
#        '41', '18', '17', 'More than 50 years', '7', '6', '50', '5', '49',
#        '28', '21', '20', '2', '14', '10', '1', nan, '11', '30', '13',
#        '27', '22', '19', '16', '34', '37', '42', '33', '26', '35', '38',
#        '36', '31', '29', '24', '23', '43', '32', '39', '45', '44', '47',
#        '48', '46'], dtype=object)

# %%
df["YearsCode"].replace("Less than 1 year", 0, inplace=True)

# %%
df["YearsCode"].replace("More than 50 years", 51, inplace=True)

# %%
df["YearsCode"] = df["YearsCode"].astype(float)

# %%
df["YearsCode"].mean()
# Out:
# 12.251307285752338

# %%
df["YearsCode"].median()
# Out:
# 9.0

# %%
saudi_filt = (df["Country"] == "Saudi Arabia")
saudi_df = df.loc[saudi_filt]
saudi_df
# Out:
#                                                    MainBranch  \
# ResponseId
# 63647                          I am a developer by profession
# 26204                          I am a developer by profession
# 12931                          I am a developer by profession
# 40541                          I am a developer by profession
# 68976                          I am a developer by profession
# ...                                                       ...
# 63287       I am not primarily a developer, but I write co...
# 10430                                   I am learning to code
# 51965                          I am a developer by profession
# 12341                             I code primarily as a hobby
# 15422                                   I am learning to code
#
#                                                    Employment  \
# ResponseId
# 63647                                     Employed, part-time
# 26204                                     Employed, full-time
# ...

# %%
saudi_df.to_csv("data/saudi.csv")

# %%
saudi_df.to_excel("data/saudi.xlsx")

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine ("postgresql://postgres:9099@localhost:5432/saudi_df")

# %%
saudi_df.to_sql('saudi_table', engine, if_exists="replace")
# Out:
# 116

# %%
sql_df = pd.read_sql("SELECT * FROM saudi_table", engine, index_col="ResponseId")

# %%
sql_df.head()
# Out:
#                                 MainBranch           Employment  \
# ResponseId
# 63647       I am a developer by profession  Employed, part-time
# 26204       I am a developer by profession  Employed, full-time
# 12931       I am a developer by profession  Employed, full-time
# 40541       I am a developer by profession  Employed, full-time
# 29090                I am learning to code   Student, full-time
#
#                                       RemoteWork  \
# ResponseId
# 63647                             Full in-person
# 26204                               Fully remote
# 12931       Hybrid (some remote, some in-person)
# 40541                             Full in-person
# 29090                                       None
#
#                                              CodingActivities  \
# ResponseId
# 63647                                                   Hobby
# 26204       Hobby;Contribute to open-source projects;Boots...
# ...

# %%
lang = df["LanguageHaveWorkedWith"]

# %%
lang.to_csv("data/saudi.csv")

# %%
corel = df[["", "YearsCode", CompTotal", "LanguageHaveWorkedWith"]].reset_index()
corel
# Out:
#        ResponseId                                          EdLevel  YearsCode  \
# 0            6892     Bachelor’s degree (B.A., B.S., B.Eng., etc.)        3.0
# 1           38513  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       40.0
# 2           43640     Bachelor’s degree (B.A., B.S., B.Eng., etc.)       12.0
# 3           43691     Bachelor’s degree (B.A., B.S., B.Eng., etc.)        8.0
# 4           23224     Bachelor’s degree (B.A., B.S., B.Eng., etc.)        9.0
# ...           ...                                              ...        ...
# 73263       73110                                              NaN        NaN
# 73264       73158                                              NaN        NaN
# 73265       73202                                              NaN        NaN
# 73266       73216                                              NaN        NaN
# 73267       73244                                              NaN        NaN
#
# ...

# %%
plt.figure(figsize=(18,8))
sns.heatmap(corel.corr(),annot=True)
plt.show()
# Out:
# /var/folders/9v/384z_l5x3tsfx1h848wkwz2r0000gn/T/ipykernel_1544/1253437236.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(corel.corr(),annot=True)
